# %% [markdown]
# # 1. เรียกใช้งาน library
# `numpy`
# `pandas`
# `matplotlib.pyplot`

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. นำเข้าข้อมูล data_sample.csv

# %%
data_sample = pd.read_csv('./datasets/data_sample.csv')

# %%
# ตรวจสอบโครงสร้างข้อมูล 
data_sample.shape   # (ROW , COLUMN)
#  ข้อมูลมี   10  แถว   มี  4  คอลัมน์ 
# แสดงข้อมูลตัวอย่าง 
data_sample.head(3)   # แสดง 5 แถวแรก 
data_sample.tail(3)   # แสดง  5 สุดท้าย 
data_sample.sample(7)  # สุ่มมาแสดง ตามจำนวนที่กำหนด 
data_sample.sample(5, random_state=1 )  # random_state กำหนดการสุ่มตัวอย่าง
# Out:
#    Country   Age   Salary Purchased
# 2  Germany  30.0  54000.0        No
# 9   France  37.0  67000.0       Yes
# 6    Spain   NaN  52000.0        No
# 4  Germany  40.0      NaN       Yes
# 0   France  44.0  72000.0        No

# %%
# สำรวจชนิดข้อมูล และรายละเอียดต่าง ๆ 
data_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes

# %%
data_sample.columns   # แสดงชื่อ Column
# Out:
# Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='object')

# %%
#  สำรวจข้อมูล โดยแสดงค่าทางสถิติ เฉพาะที่เป็นตัวเลข 
# .descripbe()
data_sample.describe()   #

# %%
#  สำรวจข้อมูล โดยแสดงค่าทางสถิติ ที่ไม่ใช่ตัวเลข 
# summary statistics categorical data 
data_sample.describe( exclude= np.number )
# Out:
#        Country Purchased
# count       10        10
# unique       3         2
# top     France        No
# freq         4         5

# %%
# เปลี่ยนประเภทข้อมูล  .astype()    
data_sample['Age'] = data_sample['Age'].astype('category')
data_sample['Age'].describe()

# แปลงกลับ  จาก category เป็น float 
data_sample['Age'] = data_sample['Age'].astype('float')

# %%
# ตรวจสอบข้อมูลสูญหาย missing value 
# .isnull()
data_sample.isnull()
data_sample.isnull().sum()

# นำมาคำนวณเป็น percent 
percent_missing_value = data_sample.isnull().sum() *100 / len(data_sample)
percent_missing_value
# Out:
# Country       0.0
# Age          10.0
# Salary       10.0
# Purchased     0.0
# dtype: float64

# %%
# แสดงข้อมูลเป็นกราฟ Visualization 
# .hist()
data_sample.hist()
plt.show()

# %%
# แสดงกราฟ การกระจาย  Scatter plot 
# Age VS Salary 
import seaborn as sns   # ถ้าไม่มี ก็ติดตั้ง pip install seaborn 
sns.scatterplot( data= data_sample, x = 'Age', y = 'Salary'  )
plt.title(" AGE VESUS SALARY ")
plt.show()

# %%
# สำรวจ outline ด้วยกราฟ Bloxplot 
sns.boxplot( x = data_sample['Age'] )
plt.show()

# %%
# สำรวจ outline ด้วยกราฟ Bloxplot 
sns.boxplot( x = data_sample['Salary'] )
plt.show()

# %%
sns.violinplot(x = data_sample['Age'])
plt.show()
