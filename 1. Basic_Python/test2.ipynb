# %% [markdown]
# # Basic python

# %%
age = 44
age
# Out:
# 44

# %% [markdown]
# # Installing package

# %%
# Installing jupyter
! pip install jupyter

# %%
# Installing numpy  ! pip  %pip
! pip install numpy

# %%
# Installing pandas 
! pip install pandas

# %% [markdown]
# 1. matplotlib 2. scikit-learn 3. openpyxl 4.seaborn
