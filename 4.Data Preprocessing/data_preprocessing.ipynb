# %% [markdown]
# ## 1. Importing Libraries and Loading the Dataset
#
# titanic
#
# df.head()

# %%
import pandas as pd
import numpy as np
titanic = pd.read_csv("./datasets/titanic.csv")
titanic.head()   # เรียกดูข้อมูลในเบื้องต้น

# %%
# col_name = titanic.columns.to_list()
# col_name

# %% [markdown]
# ## 2. Understanding the Dataset
#
# df.info()
# df.describe()
# df.columns
# df.shape

# %%
# titanic.info()

# titanic.columns
# titanic.shape
# titanic.dtypes

# %%
# convert data type
# df[col] = df[col].astype('type')  where type are [ 'object', 'category' ]
titanic['Pclass'] = titanic['Pclass'].astype('category')
titanic.info()

# %%
# summary statistics 
# titanic.describe()    
# summart statistics for categorical data 
# titanic.describe(exclude=np.number)

# %%
# count = จำนวนแถวที่ ไม่เป็น NaN
# unique = จำนวนค่าที่แตกต่างกัน (จำนวนหมวด)
# top = ค่าที่พบบ่อยที่สุด (โหมด)
#  freq = ความถี่ของค่าในแถว top (ไม่นับ NaN)

# %%
# summary = pd.concat(
#     [titanic.describe(include=np.number), titanic.describe(exclude=np.number)],
#     axis=1
# )
# summary

# %% [markdown]
# ## 3. Handling Missing Values
#
# Identify missing data (.isnull().sum())
#
# Drop missing values (.dropna())
#
# Fill missing values (.fillna() with mean, median, mode, etc.)

# %%
# titanic.isnull()   # Check null 
titanic.isnull().sum()  # ดูว่ามี missing ที่ไหนบ้าง

# %%
# Handling Missing Values 
# case I 
# ลบทิ้งทั้งแถวที่ missing
titanic_delete_na = titanic.dropna()
# titanic_delete_na.info()
# titanic.drop_duplicates(inplace=True)

# %%
# Handling Missing Values 
# case II
# แทนที่ missing ด้วย 0
titanic_replace_missing_with_zero = titanic.fillna(0)
titanic_replace_missing_with_zero.info()

# %% [markdown]
# ## 4. Encoding Categorical Variables

# %% [markdown]
# ## 5. Feature Scaling

# %% [markdown]
# ## 6. Outlier Detection and Removal

# %% [markdown]
# ## 7. Feature Selection and Engineering

# %% [markdown]
# ## 8. Final Data Check
